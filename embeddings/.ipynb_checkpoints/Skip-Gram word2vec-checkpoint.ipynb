# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

words_d = Counter(words)

def discard_prob(count, total_count, t):
    p = 1.0 - (np.sqrt(t / (count / float(total_count))))
    return p

count = len(words)

t = 0.00001
    
train_words = [vocab_to_int[word] for word in words if discard_prob(words_d[word], count, t) < random.random()]

# %% [markdown]
# ## Making batches

# %%
print(len(train_words))

print (train_words[0])
# Out:
# 4627648
# 5234

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target2(words, idx, window_size = 5):
    ''' Get a list of words in a window around an index. '''
    count = np.random.randint(1, window_size + 1)
    words_len = len(words)
    
    start = idx - count if idx - count >= 0 else 0
    stop = idx + count if idx + count < words_len else words_len - 1
    
    res = set(words[start : idx])
    
    if (idx + 1 < words_len):
        res = res | set(words[idx + 1 : stop])
        
    return list(res)

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size = 5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[ : n_batches * batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx : idx + batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300  # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros([n_vocab])) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,  labels, embed, num_sampled = n_sampled, num_classes = n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7941 0.0968 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7254 0.0894 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6256 0.0877 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7376 0.0876 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5903 0.0878 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6513 0.0890 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6355 0.0916 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6484 0.0891 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5314 0.0904 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5332 0.0881 sec/batch
# Nearest to three: npd, developments, subvert, tol, filmi, gpled, vagina, dunning,
# Nearest to would: flatted, locomotive, lui, kampuchea, acquis, suburb, rearrangements, alcohol,
# Nearest to to: hearst, melanoleuca, labelling, this, galleys, organists, commensurate, ix,
# Nearest to up: catheters, elegantly, timescale, greed, juni, shorts, solicit, abodes,
# Nearest to its: ati, slapped, deter, skilfully, durr, iata, boineburg, sawdust,
# Nearest to such: duesberg, irreversibly, pai, agility, subdivide, lecturer, tallinn, mononobe,
# Nearest to often: afterburner, dairies, cunning, impulse, garages, faire, impingement, conjugations,
# Nearest to into: amniotes, consisting, loaves, firmicutes, jovian, iptables, weinstein, relinquishment,
# Nearest to stage: serpento, bubbling, humanely, ravalomanana, combatant, grouse, wiseman, hearst,
# Nearest to lived: farrier, papert, flock, raeder, unser, marcy, axum, erina,
# Nearest to bible: telharmonium, higgins, discharging, marpol, brasil, leased, anglophones, microinstruction,
# Nearest to event: glam, gershom, nijhoff, wetton, fuji, crooks, cordovero, widgery,
# Nearest to experience: pronounce, abolitionism, bernicia, nethack, snapshot, heracles, outings, rules,
# Nearest to additional: claudel, utc, overheat, connell, pernicious, speciality, query, pegasi,
# Nearest to magazine: elamite, parentheses, vesicle, ersatz, cem, vigilant, abductions, booted,
# Nearest to frac: mincha, ine, farm, benjamin, outweighs, recieves, greve, nowadays,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5812 0.0888 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4671 0.0872 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3701 0.0970 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2961 0.0865 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2717 0.0866 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2084 0.0865 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1657 0.0910 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1059 0.0881 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0592 0.0903 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0665 0.0913 sec/batch
# Nearest to three: developments, npd, vagina, subvert, gpled, attention, tol, blackwood,
# Nearest to would: locomotive, any, branches, lui, flatted, kampuchea, cracker, escape,
# Nearest to to: this, hearst, labelling, auto, lim, ix, sneak, gains,
# Nearest to up: catheters, timescale, personality, shorts, branch, evil, elegantly, two,
# Nearest to its: deter, slapped, missiles, media, postseason, durr, believed, ati,
# Nearest to such: duesberg, irreversibly, pai, agility, lecturer, stringy, signed, tallinn,
# Nearest to often: dairies, impulse, afterburner, faire, impingement, garages, cunning, prominence,
# Nearest to into: consisting, amniotes, meaning, jovian, loaves, firmicutes, game, behaving,
# Nearest to stage: serpento, hearst, bubbling, combatant, organisations, statistical, section, eemian,
# Nearest to lived: farrier, flock, papert, unser, raeder, marcy, commercial, cube,
# Nearest to bible: telharmonium, higgins, marpol, microinstruction, galaxies, opposite, discharging, paleozoic,
# Nearest to event: glam, fuji, gershom, nijhoff, wetton, crooks, widgery, krag,
# Nearest to experience: pronounce, rules, status, abolitionism, marqu, tien, outings, garcia,
# Nearest to additional: utc, claudel, county, prevents, query, connell, itself, overheat,
# Nearest to magazine: parentheses, elamite, vesicle, ersatz, provinces, cem, vigilant, furnishings,
# Nearest to frac: mincha, nowadays, benjamin, farm, centered, executed, stand, opera,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9654 0.0882 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9641 0.0923 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9294 0.0934 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9360 0.0952 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8578 0.0903 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8923 0.0902 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8413 0.0904 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8632 0.0901 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8465 0.0902 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8555 0.0904 sec/batch
# Nearest to three: developments, npd, subvert, gpled, vagina, antoine, hydropower, haircut,
# Nearest to would: locomotive, any, suburb, branches, flatted, kampuchea, cracker, betrayed,
# Nearest to to: organists, ix, sneak, labelling, propped, hearst, melanoleuca, this,
# Nearest to up: catheters, elegantly, timescale, greed, broadened, personality, solicit, denunciations,
# Nearest to its: deter, durr, iata, postseason, slapped, dual, missiles, broadcasts,
# Nearest to such: duesberg, lecturer, pai, stringy, agility, irreversibly, tallinn, subdivide,
# Nearest to often: impulse, afterburner, dairies, faire, cunning, garages, moments, integrated,
# Nearest to into: amniotes, jovian, consisting, loaves, firmicutes, weinstein, noxious, coronado,
# Nearest to stage: serpento, combatant, hearst, bubbling, reappear, statistical, hungary, section,
# Nearest to lived: farrier, flock, unser, papert, cube, marcy, axum, raeder,
# Nearest to bible: telharmonium, higgins, galaxies, opposite, succeed, marpol, leased, caverns,
# Nearest to event: gershom, glam, fuji, crooks, wetton, nijhoff, krag, masturbating,
# Nearest to experience: pronounce, rules, status, abolitionism, bernicia, tien, input, making,
# Nearest to additional: utc, claudel, county, query, pernicious, connell, overheat, dewey,
# Nearest to magazine: parentheses, elamite, vesicle, ersatz, noises, cem, feel, vigilant,
# Nearest to frac: nowadays, mincha, centered, farm, executed, benjamin, stand, subconscious,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8378 0.0912 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8177 0.0915 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7449 0.0931 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7463 0.0901 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7622 0.0906 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7520 0.0903 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7492 0.0906 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7696 0.0904 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7507 0.0902 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6730 0.0903 sec/batch
# Nearest to three: developments, subvert, antoine, hydropower, gpled, npd, haircut, vagina,
# Nearest to would: any, locomotive, kampuchea, replies, flatted, suburb, lui, mottos,
# Nearest to to: organists, propped, sneak, ix, gangs, labelling, melanoleuca, this,
# Nearest to up: catheters, elegantly, broadened, greed, timescale, denunciations, solicit, juni,
# Nearest to its: deter, postseason, slapped, sawdust, durr, media, iata, boineburg,
# Nearest to such: duesberg, stringy, lecturer, agility, pai, irreversibly, subdivide, tallinn,
# Nearest to often: afterburner, impulse, faire, dairies, conjugations, garages, integrated, cunning,
# Nearest to into: jovian, consisting, amniotes, loaves, weinstein, firmicutes, coronado, noxious,
# Nearest to stage: combatant, serpento, bubbling, mannheim, equalizer, wabash, eemian, notch,
# Nearest to lived: farrier, flock, papert, axum, marcy, cube, raeder, unser,
# Nearest to bible: telharmonium, higgins, galaxies, intervarsity, opposite, basilides, marpol, succeed,
# Nearest to event: glam, gershom, wetton, krag, fuji, crooks, nijhoff, cordovero,
# Nearest to experience: pronounce, rules, abolitionism, status, bernicia, marqu, outings, tien,
# Nearest to additional: utc, claudel, connell, query, pernicious, overheat, dewey, pumped,
# Nearest to magazine: elamite, parentheses, ersatz, vesicle, noises, ravages, cem, representations,
# Nearest to frac: mincha, nowadays, centered, subconscious, stand, farm, geq, ine,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7188 0.0908 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7026 0.0903 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6602 0.0901 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6518 0.0898 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6630 0.0899 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6725 0.0901 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6007 0.0661 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5323 0.0906 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5251 0.0905 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4817 0.0903 sec/batch
# Nearest to three: antoine, developments, hydropower, tol, ports, npd, gpled, splendid,
# Nearest to would: replies, locomotive, kampuchea, flatted, any, oka, mottos, rearrangements,
# Nearest to to: organists, propped, this, sneak, unless, cisneros, usemodwiki, ix,
# Nearest to up: catheters, elegantly, broadened, timescale, kindi, greed, originator, solicit,
# Nearest to its: deter, sawdust, durr, ati, postseason, iata, media, slapped,
# Nearest to such: duesberg, stringy, pai, subdivide, agility, irreversibly, lecturer, conversely,
# Nearest to often: afterburner, impulse, faire, dairies, garages, conjugations, cunning, manors,
# Nearest to into: amniotes, jovian, consisting, loaves, firmicutes, noxious, weinstein, relinquishment,
# Nearest to stage: serpento, combatant, bubbling, equalizer, eemian, prequel, mannheim, wabash,
# Nearest to lived: farrier, flock, unser, papert, axum, raeder, marcy, founder,
# Nearest to bible: telharmonium, higgins, basilides, galaxies, opposite, intervarsity, succeed, marpol,
# Nearest to event: glam, gershom, wetton, fuji, krag, crooks, masturbating, nva,
# Nearest to experience: pronounce, abolitionism, rules, status, marqu, snapshot, bernicia, outings,
# Nearest to additional: query, pumped, pernicious, utc, claudel, overheat, dewey, connell,
# Nearest to magazine: parentheses, elamite, vesicle, sonic, ersatz, ravages, noises, cem,
# Nearest to frac: mincha, nowadays, subconscious, geq, centered, ine, stand, orbital,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4940 0.0908 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4876 0.0904 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4372 0.0900 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5083 0.0900 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4724 0.0901 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4543 0.0902 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4470 0.0900 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3870 0.0900 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4075 0.0902 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4211 0.0900 sec/batch
# Nearest to three: hydropower, developments, tol, npd, dunning, gpled, splendid, executes,
# Nearest to would: replies, flatted, kampuchea, any, locomotive, np, rearrangements, cracker,
# Nearest to to: organists, propped, sneak, this, unless, cisneros, lim, usemodwiki,
# Nearest to up: elegantly, catheters, kindi, walk, broadened, shorts, alimentary, timescale,
# Nearest to its: durr, deter, sawdust, postseason, muralitharan, territory, iata, slapped,
# Nearest to such: duesberg, stringy, pai, irreversibly, subdivide, asexually, agility, lecturer,
# Nearest to often: afterburner, impulse, dairies, garages, faire, conjugations, cunning, manors,
# Nearest to into: jovian, amniotes, loaves, consisting, relinquishment, the, firmicutes, noxious,
# Nearest to stage: bubbling, serpento, combatant, prequel, mannheim, humanely, equalizer, inside,
# Nearest to lived: farrier, unser, flock, raeder, papert, hooded, marcy, axum,
# Nearest to bible: telharmonium, basilides, higgins, intervarsity, galaxies, succeed, genesis, resurrection,
# Nearest to event: glam, gershom, krag, wetton, nva, fuji, masturbating, crooks,
# Nearest to experience: pronounce, rules, abolitionism, marqu, status, moonchild, outings, bernicia,
# Nearest to additional: query, pumped, claudel, pernicious, utc, connell, herm, multinomial,
# Nearest to magazine: elamite, parentheses, ravages, sonic, ersatz, noises, vesicle, girls,
# Nearest to frac: z, geq, mincha, subconscious, sqrt, nowadays, orbital, incurs,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4200 0.0912 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4144 0.0901 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4423 0.0899 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3700 0.0900 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3997 0.0900 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4463 0.0904 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3567 0.0903 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3720 0.0900 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3867 0.0901 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3544 0.0900 sec/batch
# Nearest to three: hydropower, splendid, tol, developments, gpled, executes, npd, dunning,
# Nearest to would: replies, flatted, kampuchea, any, locomotive, np, oka, cracker,
# Nearest to to: organists, propped, this, lim, sneak, cisneros, unless, force,
# Nearest to up: elegantly, kindi, catheters, walk, pyle, broadened, solicit, unsurprisingly,
# Nearest to its: durr, deter, muralitharan, ati, ets, sawdust, postseason, territory,
# Nearest to such: duesberg, lecturer, irreversibly, pai, stringy, jacobean, asexually, agility,
# Nearest to often: afterburner, garages, impulse, dairies, faire, cunning, conjugations, involving,
# Nearest to into: jovian, amniotes, loaves, consisting, relinquishment, firmicutes, weinstein, the,
# Nearest to stage: bubbling, serpento, prequel, combatant, mannheim, equalizer, notch, wiseman,
# Nearest to lived: farrier, unser, flock, marcy, hooded, papert, raeder, benhavn,
# Nearest to bible: telharmonium, basilides, intervarsity, resurrection, higgins, succeed, genesis, jesus,
# Nearest to event: glam, gershom, fuji, wetton, masturbating, krag, nva, cordovero,
# Nearest to experience: pronounce, abolitionism, rules, bernicia, outings, marqu, status, holder,
# Nearest to additional: pernicious, query, pumped, claudel, overheat, pegasi, utc, wald,
# Nearest to magazine: sonic, elamite, ravages, parentheses, ersatz, girls, shikoku, representations,
# Nearest to frac: z, geq, mincha, incurs, subconscious, sqrt, orbital, nowadays,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3907 0.0909 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3917 0.0899 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3464 0.0900 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3230 0.0900 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3788 0.0902 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3399 0.0902 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3679 0.0902 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3534 0.0905 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3170 0.0903 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3002 0.0903 sec/batch
# Nearest to three: hydropower, splendid, developments, m, executes, tol, dunning, npd,
# Nearest to would: replies, flatted, any, kampuchea, betrayed, locomotive, np, assuage,
# Nearest to to: propped, this, lim, sneak, organists, exacted, cisneros, force,
# Nearest to up: elegantly, kindi, catheters, broadened, musicum, solicit, walk, unsurprisingly,
# Nearest to its: durr, deter, territory, muralitharan, ets, ati, government, media,
# Nearest to such: duesberg, asexually, stringy, lecturer, pai, jacobean, irreversibly, agility,
# Nearest to often: afterburner, garages, impulse, dairies, cunning, conjugations, faire, caliber,
# Nearest to into: jovian, loaves, amniotes, consisting, the, relinquishment, firmicutes, noxious,
# Nearest to stage: bubbling, equalizer, prequel, serpento, notch, wildfires, eras, leffler,
# Nearest to lived: unser, farrier, flock, marcy, hooded, adriaan, papert, axum,
# Nearest to bible: telharmonium, intervarsity, genesis, basilides, resurrection, tanakh, higgins, reprint,
# Nearest to event: glam, gershom, fuji, wetton, nva, masturbating, krag, refresh,
# Nearest to experience: abolitionism, pronounce, rules, bernicia, outings, status, holder, branes,
# Nearest to additional: query, pernicious, pumped, utc, overheat, claudel, bronte, multinomial,
# Nearest to magazine: sonic, ravages, parentheses, yamaha, ersatz, elamite, feel, girls,
# Nearest to frac: geq, z, mincha, incurs, sqrt, subconscious, ine, rho,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3321 0.0911 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2935 0.0906 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3849 0.0915 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3515 0.0901 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3705 0.0951 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2837 0.0947 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2870 0.0929 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3438 0.0890 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2279 0.0884 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2696 0.0927 sec/batch
# Nearest to three: two, hydropower, one, nine, executes, splendid, antoine, tol,
# Nearest to would: replies, flatted, any, np, kampuchea, cracker, oka, assuage,
# Nearest to to: sneak, organists, lim, this, propped, cisneros, exacted, ulvaeus,
# Nearest to up: kindi, walk, elegantly, musicum, catheters, broadened, pyle, unsurprisingly,
# Nearest to its: territory, durr, postseason, deter, muralitharan, ets, ati, sawdust,
# Nearest to such: lecturer, duesberg, asexually, stringy, pai, jacobean, agility, irreversibly,
# Nearest to often: afterburner, impulse, garages, dairies, cunning, conjugations, faire, caliber,
# Nearest to into: jovian, loaves, amniotes, consisting, firmicutes, relinquishment, noxious, the,
# Nearest to stage: bubbling, wildfires, leffler, equalizer, serpento, notch, combatant, philanthropists,
# Nearest to lived: flock, unser, farrier, marcy, hooded, ywca, adriaan, benhavn,
# Nearest to bible: telharmonium, intervarsity, genesis, basilides, tanakh, resurrection, mboxx, entreaties,
# Nearest to event: glam, fuji, gershom, masturbating, wetton, nva, krag, crooks,
# Nearest to experience: abolitionism, rules, pronounce, holder, bernicia, outings, turnover, heracles,
# Nearest to additional: pumped, pernicious, claudel, overheat, query, dewey, county, uke,
# Nearest to magazine: sonic, ravages, parentheses, yamaha, ersatz, girls, shikoku, ami,
# Nearest to frac: geq, mincha, incurs, z, sqrt, rho, orbital, prod,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3170 0.0907 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2773 0.0915 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3306 0.0424 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2300 0.0917 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1784 0.0936 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1703 0.0903 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1942 0.0869 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1796 0.0870 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1847 0.0871 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1248 0.0866 sec/batch
# Nearest to three: two, hydropower, one, tol, executes, km, dunning, splendid,
# Nearest to would: flatted, replies, any, np, acquis, oka, kampuchea, cracker,
# Nearest to to: sneak, organists, lim, propped, this, heels, gangs, cisneros,
# Nearest to up: walk, kindi, musicum, catheters, arranged, locate, elegantly, liners,
# Nearest to its: durr, territory, sawdust, postseason, ets, ati, north, muralitharan,
# Nearest to such: duesberg, asexually, lecturer, pai, jamo, stringy, agility, cursus,
# Nearest to often: afterburner, impulse, garages, cunning, dairies, conjugations, monad, caliber,
# Nearest to into: loaves, jovian, amniotes, the, consisting, relinquishment, noxious, kmaq,
# Nearest to stage: bubbling, wildfires, hungary, serpento, equalizer, notch, inside, leffler,
# Nearest to lived: flock, unser, farrier, ywca, hooded, benhavn, marcy, asiatic,
# Nearest to bible: telharmonium, basilides, intervarsity, genesis, tanakh, mboxx, buddha, reprint,
# Nearest to event: glam, gershom, fuji, nva, wetton, krag, masturbating, bz,
# Nearest to experience: abolitionism, rules, pronounce, insufficient, turnover, holder, outings, moonchild,
# Nearest to additional: dewey, claudel, pumped, pernicious, county, overheat, query, connell,
# Nearest to magazine: sonic, parentheses, ravages, shikoku, yamaha, ami, noises, ersatz,
# Nearest to frac: geq, mincha, incurs, z, rho, sqrt, orbital, prod,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2208 0.0873 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1735 0.0866 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1833 0.0864 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1096 0.0876 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1706 0.0886 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1238 0.0876 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1522 0.0885 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1333 0.0871 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1735 0.0876 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1536 0.0905 sec/batch
# Nearest to three: two, one, hydropower, dunning, tol, executes, five, nine,
# Nearest to would: flatted, replies, any, np, escape, acquis, oka, laptops,
# Nearest to to: sneak, lim, draw, organists, propped, this, heels, mcdivitt,
# Nearest to up: walk, kindi, liners, locate, disregards, arranged, pursuers, catheters,
# Nearest to its: durr, ets, territory, ati, muralitharan, postseason, auto, sawdust,
# Nearest to such: duesberg, lecturer, asexually, stringy, agility, jamo, pai, cursus,
# Nearest to often: impulse, dairies, garages, afterburner, conjugations, cunning, monad, caliber,
# Nearest to into: jovian, amniotes, loaves, consisting, the, firmicutes, relinquishment, zygote,
# Nearest to stage: bubbling, equalizer, combatant, notch, serpento, philanthropists, eras, hungary,
# Nearest to lived: flock, farrier, unser, benhavn, ywca, wilberforce, hooded, papert,
# Nearest to bible: telharmonium, tanakh, genesis, intervarsity, basilides, mboxx, buddha, reprint,
# Nearest to event: glam, fuji, gershom, nva, wetton, masturbating, krag, refresh,
# Nearest to experience: abolitionism, rules, pronounce, turnover, holder, outings, insufficient, branes,
# Nearest to additional: pernicious, dewey, claudel, county, pumped, overheat, pegasi, bronte,
# Nearest to magazine: sonic, yamaha, shikoku, parentheses, ravages, girls, offers, projects,
# Nearest to frac: geq, z, rho, sqrt, mincha, orbital, incurs, pi,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1501 0.0914 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2172 0.0906 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1603 0.0904 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1276 0.0904 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1844 0.0903 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1514 0.0903 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1877 0.0904 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1273 0.0903 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1101 0.0904 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1632 0.0905 sec/batch
# Nearest to three: two, one, hydropower, five, nine, six, m, zero,
# Nearest to would: flatted, replies, any, np, escape, acquis, oka, inside,
# Nearest to to: sneak, lim, organists, the, this, draw, heels, propped,
# Nearest to up: kindi, walk, emerson, liners, swings, locate, arranged, catheters,
# Nearest to its: ets, territory, durr, ati, auto, dominions, pharsalus, muralitharan,
# Nearest to such: lecturer, duesberg, asexually, agility, jamo, cursus, stringy, irreversibly,
# Nearest to often: impulse, garages, dairies, afterburner, conjugations, cunning, gastroenterology, scoped,
# Nearest to into: jovian, amniotes, loaves, consisting, relinquishment, the, paddle, firmicutes,
# Nearest to stage: bubbling, serpento, combatant, philanthropists, leffler, hungary, equalizer, eras,
# Nearest to lived: flock, unser, farrier, ywca, wilberforce, benhavn, adriaan, papert,
# Nearest to bible: telharmonium, basilides, tanakh, intervarsity, genesis, buddha, nahum, millais,
# Nearest to event: glam, gershom, fuji, nva, wetton, krag, masturbating, rai,
# Nearest to experience: abolitionism, rules, impotence, pronounce, turnover, outings, bernicia, nethack,
# Nearest to additional: pernicious, county, dewey, overheat, bronte, pegasi, claudel, utc,
# Nearest to magazine: sonic, yamaha, ravages, shikoku, girls, ami, directors, offers,
# Nearest to frac: geq, sqrt, rho, mincha, z, pi, prod, orbital,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2070 0.0912 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1436 0.0905 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1749 0.0904 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1743 0.0904 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1348 0.0905 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1129 0.0902 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1520 0.0905 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0828 0.0907 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1694 0.0906 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1881 0.0905 sec/batch
# Nearest to three: two, one, five, nine, six, zero, seven, moyen,
# Nearest to would: flatted, replies, any, acquis, np, escape, oka, assuage,
# Nearest to to: the, sneak, organists, gangs, supervision, engelbert, their, peacocks,
# Nearest to up: kindi, emerson, swings, liners, locate, walk, comnena, musicum,
# Nearest to its: durr, territory, ets, dominions, muralitharan, oshawa, postseason, ati,
# Nearest to such: lecturer, duesberg, agility, asexually, jamo, jacobean, cursus, subculture,
# Nearest to often: impulse, garages, dairies, cunning, afterburner, conjugations, gastroenterology, revival,
# Nearest to into: jovian, loaves, amniotes, the, consisting, relinquishment, chartres, popperian,
# Nearest to stage: bubbling, combatant, philanthropists, equalizer, hungary, serpento, wildfires, eras,
# Nearest to lived: flock, farrier, ywca, wilberforce, axum, adriaan, unser, papert,
# Nearest to bible: genesis, telharmonium, basilides, intervarsity, tanakh, entreaties, millais, buddha,
# Nearest to event: glam, gershom, nva, wetton, krag, fuji, rai, masturbating,
# Nearest to experience: abolitionism, bernicia, rules, outings, impotence, turnover, nethack, jettison,
# Nearest to additional: county, pernicious, dewey, connell, bronte, pegasi, overheat, pumped,
# Nearest to magazine: sonic, yamaha, ravages, girls, offers, ami, ellery, directors,
# Nearest to frac: geq, sqrt, rho, pi, z, mincha, prod, lingala,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1908 0.0912 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1382 0.0929 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1447 0.0916 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1089 0.0932 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0234 0.0912 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1410 0.0912 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1281 0.0915 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1163 0.0884 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1646 0.0166 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0686 0.0864 sec/batch
# Nearest to three: two, one, five, nine, zero, six, executes, seven,
# Nearest to would: flatted, any, replies, np, escape, acquis, negotiating, oka,
# Nearest to to: the, organists, sneak, gangs, this, lim, their, after,
# Nearest to up: emerson, walk, kindi, locate, liners, swings, checking, downgraded,
# Nearest to its: ati, durr, territory, oshawa, ets, north, iata, postseason,
# Nearest to such: lecturer, duesberg, agility, asexually, subculture, jamo, stringy, alloys,
# Nearest to often: impulse, garages, dairies, afterburner, conjugations, gastroenterology, scoped, cunning,
# Nearest to into: amniotes, jovian, the, consisting, loaves, paddle, relinquishment, popperian,
# Nearest to stage: bubbling, equalizer, combatant, wildfires, serpento, philanthropists, otomo, hungary,
# Nearest to lived: flock, ywca, unser, farrier, benhavn, axum, wilberforce, marcy,
# Nearest to bible: telharmonium, basilides, intervarsity, genesis, tanakh, entreaties, millais, nahum,
# Nearest to event: glam, nva, gershom, wetton, fuji, krag, refresh, masturbating,
# Nearest to experience: abolitionism, impotence, rules, turnover, outings, falling, making, insufficient,
# Nearest to additional: dewey, pernicious, county, pumped, overheat, utc, pegasi, connell,
# Nearest to magazine: sonic, yamaha, girls, ami, ravages, wired, quirky, ellery,
# Nearest to frac: geq, sqrt, mincha, rho, prod, z, lingala, stand,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0397 0.0875 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0473 0.0868 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0356 0.0865 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0060 0.0863 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0592 0.0866 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9886 0.0863 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0263 0.0862 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0655 0.0863 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1079 0.0865 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9855 0.0865 sec/batch
# Nearest to three: two, one, five, nine, zero, seven, six, tol,
# Nearest to would: flatted, any, replies, np, escape, acquis, laptops, oka,
# Nearest to to: the, sneak, this, after, gangs, organists, codomain, heels,
# Nearest to up: liners, emerson, walk, swings, kindi, locate, arranged, checking,
# Nearest to its: oshawa, territory, durr, ets, north, nailed, ati, in,
# Nearest to such: lecturer, duesberg, asexually, stringy, cursus, jamo, alloys, agility,
# Nearest to often: impulse, garages, dairies, afterburner, caliber, conjugations, scoped, cunning,
# Nearest to into: amniotes, the, jovian, loaves, consisting, paddle, zygote, kmaq,
# Nearest to stage: bubbling, combatant, philanthropists, equalizer, wildfires, serpento, otomo, hungary,
# Nearest to lived: flock, farrier, ywca, unser, benhavn, axum, wilberforce, lara,
# Nearest to bible: telharmonium, genesis, basilides, intervarsity, tanakh, nahum, bibles, tanach,
# Nearest to event: glam, nva, gershom, fuji, wetton, krag, rai, notifying,
# Nearest to experience: abolitionism, impotence, rules, turnover, outings, necessitate, nethack, insufficient,
# Nearest to additional: dewey, county, pernicious, claudel, connell, pegasi, multinomial, uke,
# Nearest to magazine: sonic, girls, yamaha, wired, ami, karbala, ravages, subscribers,
# Nearest to frac: geq, sqrt, z, rho, prod, mincha, ine, pi,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9879 0.0871 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0035 0.0864 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9761 0.0867 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0276 0.0867 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0445 0.0865 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0246 0.0874 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0537 0.0865 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0594 0.0868 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0179 0.0869 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9961 0.0880 sec/batch
# Nearest to three: two, one, nine, five, zero, seven, six, hydropower,
# Nearest to would: flatted, replies, np, escape, any, deconvolution, laptops, negotiating,
# Nearest to to: the, this, lim, their, sneak, codomain, mcdivitt, find,
# Nearest to up: liners, swings, emerson, checking, walk, kindi, two, locate,
# Nearest to its: nailed, oshawa, durr, ets, dominions, territory, ati, maxwell,
# Nearest to such: lecturer, stringy, pai, irreversibly, duesberg, asexually, alloys, prosecutorial,
# Nearest to often: impulse, garages, dairies, conjugations, afterburner, gastroenterology, craftsman, cunning,
# Nearest to into: amniotes, jovian, the, consisting, paddle, loaves, zygote, relinquishment,
# Nearest to stage: bubbling, philanthropists, combatant, serpento, equalizer, wildfires, otomo, wabash,
# Nearest to lived: flock, unser, wilberforce, benhavn, farrier, ywca, marcy, lara,
# Nearest to bible: genesis, telharmonium, tanakh, basilides, intervarsity, nahum, bibles, millais,
# Nearest to event: glam, nva, wetton, krag, fuji, rai, gershom, animating,
# Nearest to experience: abolitionism, impotence, outings, rules, turnover, self, branes, moonchild,
# Nearest to additional: dewey, county, pernicious, pegasi, connell, bronte, uke, claudel,
# Nearest to magazine: sonic, yamaha, wired, girls, ami, karbala, quirky, noises,
# Nearest to frac: geq, sqrt, pi, z, mincha, prod, rho, ine,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9799 0.0872 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0297 0.0863 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0328 0.0871 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0004 0.0865 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0213 0.0872 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0254 0.0914 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0393 0.0906 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0350 0.0914 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0276 0.0906 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0209 0.0905 sec/batch
# Nearest to three: two, one, five, nine, zero, seven, six, executes,
# Nearest to would: flatted, replies, np, any, escape, laptops, negotiating, assuage,
# Nearest to to: the, sneak, this, lim, after, mcdivitt, find, exacted,
# Nearest to up: liners, swings, broadened, emerson, kindi, checking, arranged, locate,
# Nearest to its: durr, ets, nailed, dominions, ati, north, government, territory,
# Nearest to such: lecturer, pai, stringy, duesberg, subculture, asexually, agility, irreversibly,
# Nearest to often: impulse, garages, dairies, conjugations, caliber, gastroenterology, revival, craftsman,
# Nearest to into: the, jovian, amniotes, loaves, consisting, chartres, amalric, paddle,
# Nearest to stage: bubbling, combatant, hungary, philanthropists, wildfires, serpento, equalizer, wabash,
# Nearest to lived: flock, unser, wilberforce, farrier, ywca, axum, benhavn, marcy,
# Nearest to bible: genesis, intervarsity, telharmonium, basilides, tanakh, nahum, ktav, millais,
# Nearest to event: glam, nva, wetton, fuji, rai, krag, notifying, finals,
# Nearest to experience: abolitionism, outings, impotence, restrained, turnover, bernicia, rules, branes,
# Nearest to additional: dewey, county, pegasi, pernicious, bronte, connell, claudel, divination,
# Nearest to magazine: wired, yamaha, sonic, noises, quirky, karbala, girls, ami,
# Nearest to frac: geq, sqrt, rho, mincha, z, pi, ine, stand,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0163 0.0905 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9862 0.0901 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0038 0.0903 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0409 0.0904 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0744 0.0906 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0922 0.0921 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0793 0.0877 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0211 0.0884 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0246 0.0883 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0205 0.0873 sec/batch
# Nearest to three: two, one, nine, five, seven, zero, six, four,
# Nearest to would: flatted, any, np, replies, escape, laptops, negotiating, assuage,
# Nearest to to: the, lim, sneak, this, organists, find, after, heels,
# Nearest to up: liners, emerson, swings, checking, goldfish, downgraded, criminally, locate,
# Nearest to its: nailed, durr, territory, north, ets, in, krugerrand, ati,
# Nearest to such: lecturer, pai, subculture, duesberg, agility, jamo, asexually, irreversibly,
# Nearest to often: impulse, garages, dairies, conjugations, gastroenterology, caliber, revival, politely,
# Nearest to into: amniotes, jovian, the, consisting, paddle, loaves, zygote, amalric,
# Nearest to stage: bubbling, combatant, philanthropists, hungary, wildfires, equalizer, leffler, serpento,
# Nearest to lived: flock, axum, ywca, wilberforce, farrier, unser, usbc, benhavn,
# Nearest to bible: genesis, intervarsity, tanakh, telharmonium, basilides, nahum, ktav, bibles,
# Nearest to event: glam, nva, rai, krag, fuji, notifying, masturbating, wetton,
# Nearest to experience: impotence, outings, abolitionism, turnover, nethack, restrained, bernicia, cherenkov,
# Nearest to additional: dewey, county, connell, pegasi, utc, pernicious, bronte, divination,
# Nearest to magazine: yamaha, wired, noises, sonic, girls, ellery, karbala, ami,
# Nearest to frac: geq, sqrt, mincha, ine, rho, stand, prod, benjamin,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9452 0.0886 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9979 0.0884 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0142 0.0875 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9899 0.0885 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0648 0.0875 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0096 0.0829 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9832 0.0886 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9441 0.0886 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9876 0.0886 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9284 0.0885 sec/batch
# Nearest to three: two, one, nine, seven, six, five, zero, four,
# Nearest to would: flatted, replies, any, np, laptops, escape, assuage, deconvolution,
# Nearest to to: the, after, but, sneak, heels, this, lim, find,
# Nearest to up: liners, swings, checking, goldfish, arranged, emerson, vet, downgraded,
# Nearest to its: nailed, ati, north, krugerrand, xbox, accessory, oshawa, ets,
# Nearest to such: subculture, duesberg, pai, jamo, asexually, alloys, lecturer, agility,
# Nearest to often: garages, impulse, dairies, gastroenterology, caliber, politely, revival, conjugations,
# Nearest to into: the, amniotes, jovian, paddle, loaves, amalric, consisting, zygote,
# Nearest to stage: bubbling, philanthropists, combatant, equalizer, hungary, wildfires, leffler, serpento,
# Nearest to lived: flock, unser, ywca, usbc, wilberforce, axum, benhavn, marcy,
# Nearest to bible: genesis, intervarsity, tanakh, telharmonium, basilides, nahum, mamre, ktav,
# Nearest to event: glam, nva, rai, notifying, krag, fuji, newcastle, wetton,
# Nearest to experience: impotence, outings, abolitionism, turnover, bernicia, restrained, self, corwin,
# Nearest to additional: dewey, county, pegasi, connell, divination, multinomial, bronte, congruent,
# Nearest to magazine: wired, yamaha, subscribers, noises, sonic, girls, ami, offers,
# Nearest to frac: geq, sqrt, mincha, rho, ine, prod, stand, benjamin,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9648 0.0880 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9035 0.0885 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9698 0.0889 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9896 0.0885 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9516 0.0870 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9645 0.0898 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8607 0.0886 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9111 0.0880 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9009 0.0874 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9254 0.0881 sec/batch
# Nearest to three: two, one, nine, five, seven, zero, six, four,
# Nearest to would: flatted, np, any, replies, deconvolution, laptops, escape, psychopathic,
# Nearest to to: the, after, sneak, lim, that, but, find, this,
# Nearest to up: liners, swings, checking, goldfish, vet, emerson, arranged, two,
# Nearest to its: north, nailed, whose, influence, oshawa, territory, krugerrand, xbox,
# Nearest to such: alloys, lecturer, asexually, jamo, pai, subculture, stringy, duesberg,
# Nearest to often: impulse, garages, dairies, gastroenterology, craftsman, diversity, caliber, revival,
# Nearest to into: amniotes, the, paddle, consisting, jovian, zygote, loaves, chartres,
# Nearest to stage: bubbling, philanthropists, combatant, wildfires, hungary, equalizer, bloomsbury, turboprop,
# Nearest to lived: flock, ywca, unser, sandalwood, wilberforce, pterosaurs, axum, campaigning,
# Nearest to bible: genesis, tanakh, intervarsity, telharmonium, basilides, nahum, mamre, ktav,
# Nearest to event: glam, nva, rai, notifying, krag, fuji, wetton, newcastle,
# Nearest to experience: impotence, outings, bernicia, turnover, abolitionism, self, jettison, branes,
# Nearest to additional: dewey, county, pegasi, bronte, trolleybus, connell, pernicious, claudel,
# Nearest to magazine: wired, subscribers, yamaha, magazines, noises, girls, karbala, humid,
# Nearest to frac: geq, sqrt, rho, mincha, ine, prod, negating, stand,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9907 0.0896 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9754 0.0893 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9398 0.0872 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9636 0.0873 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0030 0.0868 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9003 0.0881 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9841 0.0911 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9504 0.0898 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9735 0.0892 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9895 0.0872 sec/batch
# Nearest to three: two, one, nine, five, seven, six, zero, four,
# Nearest to would: flatted, replies, np, laptops, any, deconvolution, find, escape,
# Nearest to to: the, lim, sneak, after, heteroatom, their, a, but,
# Nearest to up: liners, emerson, swings, goldfish, arranged, checking, two, vet,
# Nearest to its: nailed, seigneurial, north, whose, xbox, tried, ets, dominions,
# Nearest to such: pai, subculture, duesberg, lecturer, alloys, jamo, asexually, irreversibly,
# Nearest to often: impulse, garages, dairies, politely, gastroenterology, caliber, craftsman, visually,
# Nearest to into: amniotes, consisting, the, paddle, jovian, loaves, chartres, popperian,
# Nearest to stage: bubbling, philanthropists, combatant, hungary, bloomsbury, juniors, equalizer, emmy,
# Nearest to lived: flock, ywca, unser, wilberforce, marcy, sandalwood, benhavn, dorrit,
# Nearest to bible: genesis, tanakh, basilides, intervarsity, telharmonium, nahum, ktav, millais,
# Nearest to event: glam, notifying, nva, rai, fuji, krag, wetton, newcastle,
# Nearest to experience: impotence, outings, bernicia, self, nethack, jettison, turnover, cherenkov,
# Nearest to additional: dewey, pegasi, county, trolleybus, pernicious, bronte, connell, divination,
# Nearest to magazine: wired, magazines, yamaha, noises, subscribers, girls, newspaper, humid,
# Nearest to frac: geq, sqrt, mincha, z, rho, stand, negating, exponent,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9755 0.0892 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9434 0.0902 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9826 0.0878 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9754 0.0870 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0068 0.0869 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9529 0.0868 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9428 0.0870 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9510 0.0869 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9366 0.0872 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9928 0.0869 sec/batch
# Nearest to three: two, one, seven, five, nine, six, zero, four,
# Nearest to would: flatted, any, np, those, replies, assuage, deconvolution, negotiating,
# Nearest to to: the, that, a, but, and, lim, find, their,
# Nearest to up: liners, swings, jan, checking, defencemen, emerson, broadened, two,
# Nearest to its: nailed, tried, the, whose, north, territory, since, krugerrand,
# Nearest to such: pai, subculture, duesberg, nomura, alloys, lecturer, irreversibly, jamo,
# Nearest to often: garages, impulse, dairies, caliber, gastroenterology, politely, canines, craftsman,
# Nearest to into: the, amniotes, jovian, loaves, consisting, paddle, chartres, zygote,
# Nearest to stage: bubbling, combatant, philanthropists, hungary, leffler, emmy, eras, ushant,
# Nearest to lived: ywca, unser, flock, wilberforce, sandalwood, axum, pterosaurs, usbc,
# Nearest to bible: genesis, tanakh, telharmonium, intervarsity, basilides, nahum, ktav, mamre,
# Nearest to event: glam, notifying, nva, rai, krag, wetton, fuji, milestones,
# Nearest to experience: bernicia, outings, impotence, abolitionism, self, jettison, minnesotans, branes,
# Nearest to additional: dewey, county, pegasi, trolleybus, connell, utc, uke, bronte,
# Nearest to magazine: wired, magazines, yamaha, noises, ithacan, volume, humid, karbala,
# Nearest to frac: geq, sqrt, mincha, stand, ine, z, benjamin, negating,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9173 0.0883 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0506 0.0872 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 3.9945 0.0872 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0102 0.0868 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9118 0.0870 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9277 0.0865 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9828 0.0869 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.8647 0.0871 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9698 0.0878 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9595 0.0876 sec/batch
# Nearest to three: two, one, nine, five, seven, six, zero, four,
# Nearest to would: flatted, np, those, any, deconvolution, replies, assuage, immorality,
# Nearest to to: the, lim, that, and, find, after, a, sneak,
# Nearest to up: liners, swings, two, emerson, checking, goldfish, jan, downgraded,
# Nearest to its: nailed, xbox, krugerrand, ati, oshawa, accessory, north, tried,
# Nearest to such: pai, subculture, nomura, alloys, duesberg, irreversibly, jamo, asexually,
# Nearest to often: impulse, garages, dairies, caliber, visually, gastroenterology, canines, craftsman,
# ...
# Nearest to would: to, be, any, will, deconvolution, flatted, for, powerful,
# Nearest to to: the, that, a, and, but, this, their, of,
# Nearest to up: two, liners, goldfish, swings, most, hump, in, arranged,
# Nearest to its: it, the, in, as, this, since, mack, erat,
# Nearest to such: and, are, irreversibly, generally, succinct, including, pai, parlance,
# Nearest to often: referred, garages, barsoomian, generally, sometimes, may, craftsman, canines,
# Nearest to into: the, a, and, consisting, amniotes, zygote, through, establishing,
# Nearest to stage: bubbling, philanthropists, eras, querying, theatrical, avengers, combatant, prequel,
# Nearest to lived: ywca, jacobitism, usbc, wilberforce, pterosaurs, cortlandt, zoot, erudite,
# Nearest to bible: genesis, ktav, nahum, intervarsity, telharmonium, tanakh, echols, intro,
# Nearest to event: biathlon, flying, fangio, yaound, chlorophyll, glam, nva, milestones,
# Nearest to experience: bernicia, minnesotans, experienced, seeking, impotence, sentient, trilobite, necessitate,
# Nearest to additional: pegasi, dewey, octahedra, separate, trolleybus, uke, vocalization, divination,
# Nearest to magazine: magazines, wired, noises, parentheses, newspaper, booksellers, kbo, ithacan,
# Nearest to frac: geq, sqrt, parkhurst, converters, kohoutek, initialize, left, negating,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7858 0.0932 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8121 0.0923 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8108 0.0932 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8097 0.0915 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8255 0.0896 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8280 0.0889 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8296 0.0884 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7912 0.0887 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8434 0.0902 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8335 0.0881 sec/batch
# Nearest to three: one, two, five, nine, four, seven, six, zero,
# Nearest to would: to, any, deconvolution, flatted, will, be, those, powerful,
# Nearest to to: the, that, a, and, in, but, with, after,
# Nearest to up: two, liners, swings, most, criminally, goldfish, jan, converts,
# Nearest to its: it, since, in, the, itself, this, as, has,
# Nearest to such: and, are, irreversibly, generally, succinct, precludes, including, subculture,
# Nearest to often: referred, canines, barsoomian, sometimes, garages, generally, impulse, a,
# Nearest to into: the, and, a, establishing, chartres, consisting, by, zygote,
# Nearest to stage: philanthropists, bubbling, eras, querying, prequel, combatant, theatrical, xu,
# Nearest to lived: remained, jacobitism, ywca, italianate, sapiens, wilberforce, usbc, sandalwood,
# Nearest to bible: genesis, intervarsity, ktav, nahum, tanakh, higgins, echols, telharmonium,
# Nearest to event: flying, glam, yaound, nva, fangio, biathlon, chlorophyll, neuroscientist,
# Nearest to experience: bernicia, minnesotans, seeking, experienced, sentient, impotence, arians, trilobite,
# Nearest to additional: pegasi, octahedra, dewey, failing, bronte, trolleybus, scumm, uke,
# Nearest to magazine: magazines, wired, newspaper, noises, booksellers, parentheses, ithacan, kbo,
# Nearest to frac: geq, sqrt, converters, parkhurst, kohoutek, exponent, initialize, stake,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8174 0.0882 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8083 0.0872 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8050 0.0868 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8014 0.0872 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8926 0.0875 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8126 0.0865 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9251 0.0891 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8251 0.0879 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8593 0.0874 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7699 0.0876 sec/batch
# Nearest to three: two, one, five, nine, four, seven, zero, six,
# Nearest to would: to, any, flatted, those, will, deconvolution, be, powerful,
# Nearest to to: the, a, that, and, with, in, it, also,
# Nearest to up: liners, two, most, goldfish, swings, criminally, down, and,
# Nearest to its: the, it, in, since, as, has, itself, mack,
# Nearest to such: and, are, appellate, irreversibly, including, those, comparison, descriptors,
# Nearest to often: sometimes, referred, generally, canines, barsoomian, and, garages, impulse,
# Nearest to into: the, a, and, consisting, establishing, chartres, from, amniotes,
# Nearest to stage: philanthropists, bubbling, eras, prequel, combatant, avengers, querying, theatrical,
# Nearest to lived: italianate, ywca, wilberforce, cortlandt, usbc, jacobitism, sapiens, sandalwood,
# Nearest to bible: genesis, intervarsity, ktav, echols, telharmonium, nahum, traversed, intro,
# Nearest to event: flying, fangio, glam, neuroscientist, yaound, biathlon, chlorophyll, colson,
# Nearest to experience: bernicia, minnesotans, seeking, impotence, experienced, sentient, trilobite, necessitate,
# Nearest to additional: pegasi, dewey, trolleybus, octahedra, failing, bronte, vocalization, scumm,
# Nearest to magazine: magazines, wired, newspaper, noises, booksellers, kbo, parentheses, ithacan,
# Nearest to frac: geq, sqrt, converters, parkhurst, kohoutek, stake, chicxulub, holding,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7411 0.0877 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8394 0.0885 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7900 0.0877 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8464 0.0878 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7867 0.0894 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8352 0.0920 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8668 0.0545 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7984 0.0936 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8008 0.0923 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8118 0.0929 sec/batch
# Nearest to three: two, one, five, four, nine, seven, six, zero,
# Nearest to would: any, to, will, be, deconvolution, flatted, powerful, for,
# Nearest to to: the, a, that, and, but, with, of, also,
# Nearest to up: two, goldfish, swings, criminally, most, liners, jan, down,
# Nearest to its: it, the, in, since, has, mack, as, gions,
# Nearest to such: and, are, form, those, irreversibly, comparison, including, movements,
# Nearest to often: referred, sometimes, generally, barsoomian, garages, canines, and, a,
# Nearest to into: the, and, a, establishing, consisting, amniotes, zygote, chartres,
# Nearest to stage: bubbling, philanthropists, eras, prequel, turboprop, querying, combatant, avengers,
# Nearest to lived: italianate, remained, sapiens, jacobitism, cortlandt, ywca, wilberforce, usbc,
# Nearest to bible: genesis, intervarsity, ktav, telharmonium, nahum, higgins, echols, bateman,
# Nearest to event: yaound, chlorophyll, fangio, colson, biathlon, neuroscientist, flying, milestones,
# Nearest to experience: bernicia, minnesotans, experienced, trilobite, sentient, seeking, impotence, arians,
# Nearest to additional: pegasi, dewey, vocalization, octahedra, hass, uke, trolleybus, scumm,
# Nearest to magazine: magazines, wired, newspaper, noises, booksellers, parentheses, kbo, ithacan,
# Nearest to frac: geq, sqrt, converters, parkhurst, holding, kohoutek, chicxulub, stake,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8027 0.0935 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8018 0.0941 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8076 0.0934 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7580 0.0928 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8054 0.0901 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8159 0.0901 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8603 0.0912 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7059 0.0916 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7684 0.0900 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7568 0.0900 sec/batch
# Nearest to three: two, one, five, four, seven, nine, zero, eight,
# Nearest to would: be, to, any, will, deconvolution, flatted, for, those,
# Nearest to to: the, a, and, that, is, with, also, an,
# Nearest to up: two, goldfish, down, most, liners, swings, criminally, lower,
# Nearest to its: it, the, in, has, as, since, an, this,
# Nearest to such: and, are, form, those, irreversibly, comparison, also, including,
# Nearest to often: referred, sometimes, a, generally, rather, may, craftsman, canines,
# Nearest to into: and, a, the, establishing, consisting, by, zygote, amniotes,
# Nearest to stage: bubbling, philanthropists, eras, querying, prequel, steppenwolf, avengers, unplugged,
# Nearest to lived: sapiens, ywca, remained, italianate, jacobitism, cortlandt, boone, usbc,
# Nearest to bible: genesis, intervarsity, nahum, ktav, tanakh, traversed, telharmonium, intro,
# Nearest to event: yaound, chlorophyll, fangio, biathlon, glam, flying, neuroscientist, krag,
# Nearest to experience: bernicia, experienced, sentient, minnesotans, seeking, impotence, trilobite, arians,
# Nearest to additional: pegasi, dewey, octahedra, vocalization, uke, hass, trolleybus, separate,
# Nearest to magazine: magazines, wired, newspaper, noises, kbo, booksellers, parentheses, ithacan,
# Nearest to frac: geq, sqrt, converters, parkhurst, kohoutek, holding, chicxulub, exponent,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7289 0.0921 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8043 0.0915 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8056 0.0898 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7650 0.0900 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7621 0.0910 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8551 0.0890 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8284 0.0933 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7776 0.0929 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7764 0.0924 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7736 0.0927 sec/batch
# Nearest to three: two, one, four, five, seven, nine, six, eight,
# Nearest to would: be, to, will, flatted, any, deconvolution, those, inconspicuous,
# Nearest to to: the, a, and, that, but, this, also, of,
# Nearest to up: two, liners, goldfish, down, swings, most, six, lower,
# Nearest to its: it, the, in, as, has, since, this, itself,
# Nearest to such: and, are, comparison, generally, irreversibly, form, also, including,
# Nearest to often: referred, sometimes, may, a, barsoomian, generally, as, and,
# Nearest to into: the, a, and, establishing, consisting, jovian, amniotes, from,
# Nearest to stage: philanthropists, bubbling, querying, eras, prequel, combatant, steppenwolf, unplugged,
# Nearest to lived: sapiens, italianate, jacobitism, cortlandt, ywca, usbc, remained, boone,
# Nearest to bible: genesis, ktav, intervarsity, nahum, echols, responded, traversed, bateman,
# Nearest to event: fangio, chlorophyll, flying, biathlon, colson, yaound, krag, glam,
# Nearest to experience: bernicia, experienced, minnesotans, sentient, seeking, trilobite, impotence, arians,
# Nearest to additional: pegasi, dewey, octahedra, vocalization, trolleybus, uke, hass, scumm,
# Nearest to magazine: magazines, wired, newspaper, noises, kbo, booksellers, parentheses, ithacan,
# Nearest to frac: geq, sqrt, converters, parkhurst, holding, kohoutek, initialize, corsica,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8088 0.0936 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7900 0.0931 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7994 0.0932 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8119 0.0931 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8258 0.0928 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8156 0.0932 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8059 0.0930 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7996 0.0931 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7978 0.0927 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7735 0.0930 sec/batch
# Nearest to three: two, one, five, four, seven, six, nine, zero,
# Nearest to would: any, to, will, flatted, be, deconvolution, not, that,
# Nearest to to: the, a, and, that, of, is, it, also,
# Nearest to up: two, down, goldfish, liners, swings, lower, most, six,
# Nearest to its: the, it, in, as, has, since, an, of,
# Nearest to such: and, are, generally, comparison, irreversibly, those, form, movements,
# Nearest to often: sometimes, referred, a, usually, generally, may, rather, known,
# Nearest to into: a, the, and, establishing, by, consisting, from, through,
# Nearest to stage: eras, philanthropists, querying, bubbling, prequel, emmy, xu, avengers,
# Nearest to lived: sapiens, italianate, jacobitism, usbc, cortlandt, tusks, pterosaurs, boone,
# Nearest to bible: genesis, intervarsity, ktav, nahum, echols, tanakh, traversed, bateman,
# Nearest to event: fangio, chlorophyll, yaound, krag, biathlon, flying, colson, wetton,
# Nearest to experience: bernicia, seeking, experienced, minnesotans, trilobite, sentient, arians, brand,
# Nearest to additional: pegasi, octahedra, dewey, scumm, vocalization, trolleybus, bronte, failing,
# Nearest to magazine: magazines, wired, newspaper, noises, kbo, booksellers, parentheses, ithacan,
# Nearest to frac: geq, sqrt, converters, parkhurst, holding, kohoutek, jacob, initialize,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8475 0.0938 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8371 0.0932 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8901 0.0930 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8703 0.0929 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8466 0.0927 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8440 0.0929 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7403 0.0925 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8153 0.0928 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7044 0.0931 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8310 0.0928 sec/batch
# Nearest to three: two, one, four, five, nine, seven, six, zero,
# Nearest to would: any, flatted, to, will, that, deconvolution, be, signor,
# Nearest to to: the, a, that, and, with, also, it, of,
# Nearest to up: liners, two, goldfish, swings, criminally, down, synchronised, arranged,
# Nearest to its: it, the, as, has, in, an, itself, since,
# Nearest to such: and, are, comparison, generally, to, form, those, also,
# Nearest to often: generally, sometimes, a, referred, known, usually, as, such,
# Nearest to into: a, the, establishing, and, consisting, from, parts, amniotes,
# Nearest to stage: philanthropists, bubbling, avengers, eras, querying, xu, steppenwolf, emmy,
# Nearest to lived: sapiens, italianate, usbc, jacobitism, boone, journalistic, cortlandt, tusks,
# Nearest to bible: genesis, ktav, intervarsity, traversed, bateman, nahum, responded, echols,
# Nearest to event: fangio, glam, colson, yaound, krag, flying, chlorophyll, neuroscientist,
# Nearest to experience: bernicia, experienced, seeking, minnesotans, trilobite, sentient, forwarding, brand,
# Nearest to additional: pegasi, dewey, octahedra, scumm, defibrillator, vocalization, uke, bronte,
# Nearest to magazine: magazines, wired, newspaper, noises, parentheses, kbo, booksellers, clapping,
# Nearest to frac: geq, sqrt, converters, parkhurst, holding, initialize, jacob, kohoutek,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8041 0.0938 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8054 0.0931 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
